# %% [markdown]
# <a href="https://colab.research.google.com/github/YASHASHRIH2002/RealtyForecast/blob/main/Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-43fd11e8-e028-43e7-832a-7956eabcb935" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43fd11e8-e028-43e7-832a-7956eabcb935">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %% [markdown]
# Loading and Explorating the data

# %%
import pandas as pd

df=pd.read_csv('House Price India.csv')
house_price=df.copy()
print("\nFirst 5 rows of the dataset:\n",house_price.head())
print("\nNull values in the dataset:\n",house_price.isnull().sum())
print("\nDescription of the dataset:\n",house_price.describe())
# Out:
# First 5 rows of the dataset:
#             id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810635  42491                   4                 2.50         2920
# 1  6762810998  42491                   5                 2.75         2910
# 2  6762812605  42491                   4                 2.50         3310
# 3  6762812919  42491                   3                 2.00         2710
# 4  6762813105  42491                   3                 2.50         2600
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      4000               1.5                   0                0
# 1      9480               1.5                   0                0
# 2     42998               2.0                   0                0
# 3      4500               1.5                   0                0
# 4      4750               1.0                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# Preparing the data

# %%
#spliting the data into features(X) and targets(y)
X = house_price[['living area','number of bathrooms','Built Year','number of floors','Area of the house(excluding basement)']]

y=house_price[['Price']]

# %% [markdown]
# Spliting the data into training and Testing sets

# %%
from sklearn.model_selection import train_test_split

#spliting the data
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size=0.8, random_state=42)

# %% [markdown]
# Training the model

# %%
model=LinearRegression()
model .fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Making Predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# Evaluating the Model

# %%
from sklearn.metrics import mean_squared_error, r2_score
#calculating the Mean Squre Error
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 64234855693.36183

# %% [markdown]
# Visualizing the results

# %%
import matplotlib.pyplot as plt

#making scatter plot of actual vs predicted prices
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(),y_test.max()],[y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted prices')
plt.title('Actual vs Predicted House Prices')
# Out:
# Text(0.5, 1.0, 'Actual vs Predicted House Prices')

# %% [markdown]
# Save and Document

# %%
import joblib
joblib.dump(model,'house_price_model.pk1')
# Out:
# ['house_price_model.pk1']
